# %% [markdown]
# # Hello Sphinx

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Creating a dummy Pandas dataframe

# %%
df = pd.DataFrame(np.random.randn(50,2))

# %% [markdown]
# ## How does the dataframe display render?

# %% [markdown]
# ### How does the dataframe display render nested menus?

# %%
df.head()
# Out:
#           0         1
# 0 -0.551761 -0.353121
# 1  0.379328  0.821495
# 2  0.472493 -1.292417
# 3  0.264048 -0.493651
# 4 -0.961724 -1.217368

# %% [markdown]
# ## What about plots?

# %%
df.plot();
