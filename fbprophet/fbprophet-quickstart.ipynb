# %%
# Python
import pandas as pd
import numpy as np
from fbprophet import Prophet

#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Python
df = pd.read_csv('example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2905 entries, 0 to 2904
# Data columns (total 2 columns):
# ds    2905 non-null object
# y     2905 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 45.5+ KB

# %%
m = Prophet()
m.fit(df)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.199561    7.509645    8.947434
# 3266 2017-01-16  8.524560    7.774178    9.182870
# 3267 2017-01-17  8.311920    7.580868    9.018304
# 3268 2017-01-18  8.144517    7.432871    8.879891
# 3269 2017-01-19  8.156377    7.388709    8.890159

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);
